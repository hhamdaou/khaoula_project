# %%
questions = {'q1': "1: Quelle est la définition de formation et de développement des compétences ?",
              'q2': "2: Qu'elle est la différence entre la formation traditionnelle et l'ingénieur de la formation?",
                'q3': "3: Quels critères guident le choix de la formation pour chaque employé ?", 
                'q4': "4: Quel est l'impact de la formation sur le développement des compétences ?", 
                'q5': "5: Comment le développement des compétences contribue-t-il à la croissance professionnelle des individus et à la réussite organisationnelle?"}
answers={'q1': "1: L'ingénierie de formation et développement de compétences est un processus systématique visant à concevoir, mettre en œuvre et évaluer des programmes de formation et de développement afin de répondre aux besoins en compétences des individus et des organisations. Cela implique l'identification des besoins en formation, la conception de programmes adaptés, la mise en place de méthodes d'apprentissage efficaces, et l'évaluation des résultats pour assurer l'efficacité et la pertinence des formations.",
          'q2': "2: la différence réside principalement dans la méthode adoptée par chacune des deux approches puisque la formation traditionnelle revêt plutôt une forme standard engendrant l'hypothèse que tous les individus doivent être former de la même méthode or ce n'est aucunement le cas, c'est pourquoi l'ingenierie de la formation est intervenue pour personnalisé ou bien spécifié l'étude de chaque employé dont le but de cerner le vrai besoin en compétences de chaque individu. on parle donc en premier lieu d'une approche standard et générale alors qu'en second lieu elle prend plutôt une forme innovante et personnalisée.", 
          'q3': "3: Les critères qui guident le choix de la formation pour chaque employé peuvent inclure le niveau d'expérience actuel, les compétences nécessaires pour le poste actuel ou futur, les besoins de développement professionnel, les objectifs de carrière individuels, les lacunes identifiées lors de l'évaluation de performance, les exigences de l'entreprise ou de l'industrie, et les tendances du marché du travail.", 
          'q4': "4: Acquisition de nouvelles compétences : La formation permet aux individus d'acquérir de nouvelles compétences techniques, professionnelles et personnelles, ce qui les rend plus compétents dans leur domaine. Mise à jour des connaissances : Les formations offrent l'opportunité de se tenir informé des dernières avancées, des nouvelles technologies et des meilleures pratiques, assurant ainsi une mise à jour continue des connaissances. Amélioration des performances : En développant des compétences spécifiques, les individus peuvent améliorer leurs performances dans leur travail, ce qui peut se traduire par une productivité accrue et des résultats de meilleure qualité. Adaptation aux changements : Les formations aident les individus à s'adapter aux évolutions de leur domaine, aux nouvelles exigences du marché et aux changements organisationnels, ce qui favorise leur employabilité et leur capacité à évoluer professionnellement.", 
          'q5': "5: Le développement des compétences est crucial pour l'évolution professionnelle des individus et le succès des entreprises. Pour les individus, cela signifie une employabilité renforcée, une meilleure adaptabilité, et des perspectives de carrière élargies. Pour les organisations, cela se traduit par une productivité accrue, une innovation stimulée, et une rétention améliorée des talents, contribuant à leur compétitivité et à la réalisation de leurs objectifs stratégiques. En bref, le développement des compétences est un levier essentiel pour la croissance individuelle et organisationnelle."}

# %%
print('*'*50)
print('Bonjour, je peux répondre aux questions suivantes :')
print('*'*50)
print('*'*50)

for i in questions:
    print(questions[i])
# Ask the user for input
#user_input = input("Please enter a number: ")
print('*'*50)

# Display the input back to the user
print("Votre question est: ", questions["q"+str(user_input)])
print('*'*100)

print("La réponse est: ",answers["q"+str(user_input)])
print('*'*50)
print('*'*25,'Au revoir','*'*25)
# Out:
# **************************************************
# Bonjour, je peux répondre aux questions suivantes :
# **************************************************
# **************************************************
# 1: Quelle est la définition de formation et de développement des compétences ?
# 2: Qu'elle est la différence entre la formation traditionnelle et l'ingénieur de la formation?
# 3: Quels critères guident le choix de la formation pour chaque employé ?
# 4: Quel est l'impact de la formation sur le développement des compétences ?
# 5: Comment le développement des compétences contribue-t-il à la croissance professionnelle des individus et à la réussite organisationnelle?
# **************************************************
# Votre question est:  1: Quelle est la définition de formation et de développement des compétences ?
# ****************************************************************************************************
# ...
