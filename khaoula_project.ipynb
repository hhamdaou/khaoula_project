# %%
questions = {'q1': 'qui', 'q2': 'comment', 'q3': 'quoi', 'q4': 'quand', 'q5': 'ou'}
answers={'q1': 'Khaoula rass lbatata nnnnn n nn nn n n n n n n n n n n n n n n n nn n n nn n nn n n nn',
          'q2': 'apple', 
          'q3': 'milk', 
          'q4': '12:00', 
          'q5': 'Fes'}

# %%
print('Hi I can answer the following questions')
for i in questions:
    print(questions[i])
# Ask the user for input
user_input = input("Please enter a number: ")

# Display the input back to the user
print("You entered: ", questions["q"+str(user_input)])
print("the answer is: ",answers["q"+str(user_input)])
# Out:
# Hi I can answer the following questions
# qui
# comment
# quoi
# quand
# ou
# Please enter a number:  1
# You entered:  qui
# the answer is:  Khaoula rass lbatata nnnnn n nn nn n n n n n n n n n n n n n n n nn n n nn n nn n n nn
